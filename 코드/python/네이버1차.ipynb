# %%
import hashlib
import hmac
import base64
import time
import random
import requests


class Signature:

    @staticmethod
    def generate(timestamp, method, uri, secret_key):
        message = "{}.{}.{}".format(timestamp, method, uri)
        hash = hmac.new(bytes(secret_key, "utf-8"), bytes(message, "utf-8"), hashlib.sha256)

        hash.hexdigest()
        return base64.b64encode(hash.digest())
    

def get_header(method, uri, api_key, secret_key, customer_id):
    timestamp = str(round(time.time() * 1000))
    signature = Signature.generate(timestamp, method, uri, SECRET_KEY)
    return {'Content-Type': 'application/json; charset=UTF-8', 'X-Timestamp': timestamp, 'X-API-KEY': API_KEY, 'X-Customer': str(CUSTOMER_ID), 'X-Signature': signature}


BASE_URL = 'https://api.searchad.naver.com'
API_KEY = '0100000000035ba1cc76db8c4cba24a05c3386d0f6d65e4245c883e3e70d24d46fd57193bb'
SECRET_KEY = 'AQAAAAADW6HMdtuMTLokoFwzhtD2hVgWxTOrgKQdi8s+So+KlA=='
CUSTOMER_ID = '1673134'


# 캠페인 리스트

uri = '/ncc/campaigns'
method = 'GET'
r = requests.get(BASE_URL + uri, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))

print("response status_code = {}".format(r.status_code))
print("response body = {}".format(r.json()))
campaign_list = r.json()


# 광고그룹 리스트

uri = '/ncc/adgroups'
method = 'GET'
r = requests.get(BASE_URL + uri, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))

print("response status_code = {}".format(r.status_code))
print("response body = {}".format(r.json()))
adgroup_list = r.json()


adgroup_id_list = []
for i in adgroup_list:
    adgroup_id_list.append(i['nccAdgroupId'])


# 키워드 리스트
keyword_list = []

for adgroup_id in adgroup_id_list:
    uri = '/ncc/keywords'
    method = 'GET'
    r = requests.get(BASE_URL + uri, params={'nccAdgroupId': adgroup_id}, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))
    keyword_list.append(r.json())


keyword_id = []

for i in keyword_list:
    for j in i:
        keyword_id.append(j['nccKeywordId'])
# Out:
# response status_code = 200
# response body = [{'nccCampaignId': 'cmp-a001-01-000000005188252', 'customerId': 1673134, 'name': 'P_판토모나', 'userLock': False, 'campaignTp': 'WEB_SITE', 'deliveryMethod': 'ACCELERATED', 'trackingUrl': 'https://health.phytoway.com/landing/ad?n_final_url={final_url}&n_campaign={campaign}&n_ad_group={ad_group}&n_media={media}&n_ad={ad}&n_ad_extension={ad_extension}&n_keyword={keyword}&n_keyword_id={keyword_id}&n_query={query}&n_match={match}&n_network={network}&n_rank={rank}&n_ad_group_type={ad_group_type}&n_campaign_type={campaign_type}&n_product=판토모나', 'trackingMode': 'AUTO_TRACKING_MODE', 'usePeriod': False, 'dailyBudget': 500000, 'useDailyBudget': True, 'totalChargeCost': 78716, 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 5698, 'migType': 0, 'delFlag': False, 'regTm': '2022-03-15T06:42:31.000Z', 'editTm': '2022-12-23T00:24:24.000Z'}, {'nccCampaignId': 'cmp-a001-01-000000005188261', 'customerId': 1673134, 'name': 'P_싸이토팜', 'userLock': False, 'campaignTp': 'WEB_SITE', 'deliveryMethod': 'ACCELERATED', 'trackingUrl': 'https://health.phytoway.com/landing/ad?n_final_url={final_url}&n_campaign={campaign}&n_ad_group={ad_group}&n_media={media}&n_ad={ad}&n_ad_extension={ad_extension}&n_keyword={keyword}&n_keyword_id={keyword_id}&n_query={query}&n_match={match}&n_network={network}&n_rank={rank}&n_ad_group_type={ad_group_type}&n_campaign_type={campaign_type}&n_product=싸이토팜', 'trackingMode': 'AUTO_TRACKING_MODE', 'usePeriod': False, 'dailyBudget': 200000, 'useDailyBudget': True, 'totalChargeCost': 2860, 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 1298, 'migType': 0, 'delFlag': False, 'regTm': '2022-03-15T06:43:36.000Z', 'editTm': '2022-11-05T10:51:38.000Z'}, {'nccCampaignId': 'cmp-a001-01-000000005188272', 'customerId': 1673134, 'name': 'P_루테콤', 'userLock': False, 'campaignTp': 'WEB_SITE', 'deliveryMethod': 'ACCELERATED', 'trackingUrl': 'https://health.phytoway.com/landing/ad?n_final_url={final_url}&n_campaign={campaign}&n_ad_group={ad_group}&n_media={media}&n_ad={ad}&n_ad_extension={ad_extension}&n_keyword={keyword}&n_keyword_id={keyword_id}&n_query={query}&n_match={match}&n_network={network}&n_rank={rank}&n_ad_group_type={ad_group_type}&n_campaign_type={campaign_type}&n_product=루테콤', 'trackingMode': 'AUTO_TRACKING_MODE', 'usePeriod': False, 'dailyBudget': 100000, 'useDailyBudget': True, 'totalChargeCost': 0, 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 3410, 'migType': 0, 'delFlag': False, 'regTm': '2022-03-15T06:44:50.000Z', 'editTm': '2022-11-05T10:51:16.000Z'}, {'nccCampaignId': 'cmp-a001-01-000000005192818', 'customerId': 1673134, 'name': 'P_판토모나샴푸', 'userLock': False, 'campaignTp': 'WEB_SITE', 'deliveryMethod': 'ACCELERATED', 'trackingUrl': 'https://health.phytoway.com/landing/ad?n_final_url={final_url}&n_campaign={campaign}&n_ad_group={ad_group}&n_media={media}&n_ad={ad}&n_ad_extension={ad_extension}&n_keyword={keyword}&n_keyword_id={keyword_id}&n_query={query}&n_match={match}&n_network={network}&n_rank={rank}&n_ad_group_type={ad_group_type}&n_campaign_type={campaign_type}&n_product=판토모나샴푸', 'trackingMode': 'AUTO_TRACKING_MODE', 'usePeriod': False, 'dailyBudget': 10000, 'useDailyBudget': True, 'totalChargeCost': 0, 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 1166, 'migType': 0, 'delFlag': False, 'regTm': '2022-03-16T06:27:35.000Z', 'editTm': '2022-11-05T10:52:41.000Z'}, {'nccCampaignId': 'cmp-a001-01-000000005617762', 'customerId': 1673134, 'name': 'P_트리플마그네슘', 'userLock': False, 'campaignTp': 'WEB_SITE', 'deliveryMethod': 'ACCELERATED', 'trackingUrl': 'https://health.phytoway.com/landing/ad?n_final_url={final_url}&n_campaign={campaign}&n_ad_group={ad_group}&n_media={media}&n_ad={ad}&n_ad_extension={ad_extension}&n_keyword={keyword}&n_keyword_id={keyword_id}&n_query={query}&n_match={match}&n_network={network}&n_rank={rank}&n_ad_group_type={ad_group_type}&n_campaign_type={campaign_type}&n_product=마그네슘', 'trackingMode': 'AUTO_TRACKING_MODE', 'usePeriod': F ...
# response status_code = 200
# response body = [{'nccAdgroupId': 'grp-a001-01-000000026220179', 'customerId': 1673134, 'nccCampaignId': 'cmp-a001-01-000000005188252', 'mobileChannelId': 'bsn-a001-00-000000002363216', 'pcChannelId': 'bsn-a001-00-000000002363216', 'bidAmt': 70, 'name': '비오틴_PC', 'userLock': False, 'useDailyBudget': False, 'useKeywordPlus': False, 'keywordPlusWeight': 0, 'contentsNetworkBidAmt': 70, 'useCntsNetworkBidAmt': False, 'mobileNetworkBidWeight': 10, 'pcNetworkBidWeight': 100, 'dailyBudget': 0, 'budgetLock': False, 'delFlag': False, 'regTm': '2022-03-15T06:42:54.000Z', 'editTm': '2022-12-23T01:26:51.000Z', 'targetSummary': {'pcMobile': 'partially', 'media': 'partially'}, 'pcChannelKey': 'https://smartstore.naver.com/promadelife', 'mobileChannelKey': 'https://smartstore.naver.com/promadelife', 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 5280, 'migType': 0, 'adgroupAttrJson': {'campaignTp': 1}, 'adRollingType': 'PERFORMANCE', 'adgroupType': 'WEB_SITE', 'systemBiddingType': 'NONE', 'useCntsNetworkBidWeight': False, 'contentsNetworkBidWeight': 100, 'sharedBudgetLock': False}, {'nccAdgroupId': 'grp-a001-01-000000026220194', 'customerId': 1673134, 'nccCampaignId': 'cmp-a001-01-000000005188261', 'mobileChannelId': 'bsn-a001-00-000000002363216', 'pcChannelId': 'bsn-a001-00-000000002363216', 'bidAmt': 70, 'name': 'MSM_MO', 'userLock': False, 'useDailyBudget': True, 'useKeywordPlus': False, 'keywordPlusWeight': 0, 'contentsNetworkBidAmt': 70, 'useCntsNetworkBidAmt': False, 'mobileNetworkBidWeight': 100, 'pcNetworkBidWeight': 10, 'dailyBudget': 40000, 'budgetLock': False, 'delFlag': False, 'regTm': '2022-03-15T06:43:45.000Z', 'editTm': '2022-09-29T02:38:19.000Z', 'targetSummary': {'pcMobile': 'partially', 'media': 'partially'}, 'pcChannelKey': 'https://smartstore.naver.com/promadelife', 'mobileChannelKey': 'https://smartstore.naver.com/promadelife', 'status': 'ELIGIBLE', 'statusReason': 'ELIGIBLE', 'expectCost': 1298, 'migType': 0, 'adgroupAttrJson': {'campaignTp': 1}, 'adRollingType': 'PERFORMANCE', 'adgroupType': 'WEB_SITE', 'systemBiddingType': 'NONE', 'useCntsNetworkBidWeight': False, 'contentsNetworkBidWeight': 100, 'sharedBudgetLock': False}, {'nccAdgroupId': 'grp-a001-01-000000026222097', 'customerId': 1673134, 'nccCampaignId': 'cmp-a001-01-000000005188272', 'mobileChannelId': 'bsn-a001-00-000000002363216', 'pcChannelId': 'bsn-a001-00-000000002363216', 'bidAmt': 70, 'name': '루테인_MO', 'userLock': True, 'useDailyBudget': False, 'useKeywordPlus': False, 'keywordPlusWeight': 0, 'contentsNetworkBidAmt': 70, 'useCntsNetworkBidAmt': False, 'mobileNetworkBidWeight': 100, 'pcNetworkBidWeight': 10, 'dailyBudget': 0, 'budgetLock': False, 'delFlag': False, 'regTm': '2022-03-15T07:44:23.000Z', 'editTm': '2022-09-29T03:02:48.000Z', 'targetSummary': {'pcMobile': 'partially', 'media': 'partially'}, 'pcChannelKey': 'https://smartstore.naver.com/promadelife', 'mobileChannelKey': 'https://smartstore.naver.com/promadelife', 'status': 'PAUSED', 'statusReason': 'GROUP_PAUSED', 'expectCost': 5434, 'migType': 0, 'adgroupAttrJson': {'campaignTp': 1}, 'adRollingType': 'PERFORMANCE', 'adgroupType': 'WEB_SITE', 'systemBiddingType': 'NONE', 'useCntsNetworkBidWeight': False, 'contentsNetworkBidWeight': 100, 'sharedBudgetLock': False}, {'nccAdgroupId': 'grp-a001-01-000000026238480', 'customerId': 1673134, 'nccCampaignId': 'cmp-a001-01-000000005192818', 'mobileChannelId': 'bsn-a001-00-000000002363216', 'pcChannelId': 'bsn-a001-00-000000002363216', 'bidAmt': 70, 'name': '샴푸_MO', 'userLock': False, 'useDailyBudget': False, 'useKeywordPlus': False, 'keywordPlusWeight': 0, 'contentsNetworkBidAmt': 70, 'useCntsNetworkBidAmt': False, 'mobileNetworkBidWeight': 100, 'pcNetworkBidWeight': 10, 'dailyBudget': 0, 'budgetLock': False, 'delFlag': False, 'regTm': '2022-03-16T06:27:38.000Z', 'editTm': '2022-09-29T02:40:43.000Z', 'targetSummary': {'pcMobile': 'partially', 'media': 'partially'}, 'pcChannelKey': 'https://smartstore.naver.com/promadelife', 'mobileChanne ...

# %%
import pandas as pd
df1 = pd.DataFrame(campaign_list)
df2 = pd.DataFrame(adgroup_list)
df3 = pd.DataFrame()
for i in keyword_list:
    df = pd.DataFrame(i)
    df3 = pd.concat([df3, df])

# %%
df3
# Out:
#                    nccKeywordId       keyword  customerId  \
# 0   nkw-a001-01-000004406425637         비오틴효과     1673134
# 1   nkw-a001-01-000004406425638         비오틴효능     1673134
# 2   nkw-a001-01-000004406425639        비오틴영양제     1673134
# 3   nkw-a001-01-000004406425640         비오틴추천     1673134
# 4   nkw-a001-01-000004406425641      비오틴영양제추천     1673134
# ..                          ...           ...         ...
# 25  nkw-a001-04-000005212824355        싸이토팜효능     1673134
# 26  nkw-a001-04-000005212824356     싸이토팜관절영양제     1673134
# 27  nkw-a001-04-000005212824357        싸이토팜후기     1673134
# 28  nkw-a001-04-000005283554849     싸이토팜연골영양제     1673134
# 29  nkw-a001-04-000005283554850  싸이토팜관절식물성MSM     1673134
#
#                    nccAdgroupId                nccCampaignId  userLock  \
# 0   grp-a001-01-000000026220179  cmp-a001-01-000000005188252      True
# 1   grp-a001-01-000000026220179  cmp-a001-01-000000005188252     False
# 2   grp-a001-01-000000026220179  cmp-a001-01-000000005188252      True
# 3   grp-a001-01-000000026220179  cmp-a001-01-000000005188252      True
# 4   grp-a001-01-000000026220179  cmp-a001-01-000000005188252     False
# ..                          ...                          ...       ...
# 25  grp-a001-04-000000031586229  cmp-a001-04-000000006205079     False
# 26  grp-a001-04-000000031586229  cmp-a001-04-000000006205079     False
# 27  grp-a001-04-000000031586229  cmp-a001-04-000000006205079     False
# 28  grp-a001-04-000000031586229  cmp-a001-04-000000006205079     False
# 29  grp-a001-04-000000031586229  cmp-a001-04-000000006205079     False
#
#    inspectStatus  bidAmt  useGroupBidAmt  delFlag                     regTm  \
# 0       APPROVED    3410           False    False  2022-03-16T06:41:31.000Z
# 1       APPROVED    3590           False    False  2022-03-16T06:41:31.000Z
# 2       APPROVED    4100           False    False  2022-03-16T06:41:31.000Z
# 3       APPROVED    3400           False    False  2022-03-16T06:41:31.000Z
# 4       APPROVED    2410           False    False  2022-03-16T06:41:31.000Z
# ..           ...     ...             ...      ...                       ...
# 25      APPROVED      70            True    False  2023-03-08T01:39:38.000Z
# 26      APPROVED      70            True    False  2023-03-08T01:39:38.000Z
# 27      APPROVED      70            True    False  2023-03-08T01:39:38.000Z
# 28      APPROVED      70            True    False  2023-04-06T02:22:53.000Z
# 29      APPROVED      70            True    False  2023-04-06T02:22:53.000Z
#
#                       editTm    status    statusReason attr           nccQi
# 0   2022-08-23T02:43:58.000Z    PAUSED  KEYWORD_PAUSED   {}  {'qiGrade': 4}
# 1   2023-03-23T00:05:48.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# 2   2023-01-13T07:08:51.000Z    PAUSED  KEYWORD_PAUSED   {}  {'qiGrade': 4}
# 3   2022-09-06T01:35:12.000Z    PAUSED  KEYWORD_PAUSED   {}  {'qiGrade': 4}
# 4   2022-06-20T01:43:23.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# ..                       ...       ...             ...  ...             ...
# 25  2023-03-08T05:05:30.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# 26  2023-03-08T05:05:30.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# 27  2023-03-08T05:05:30.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# 28  2023-04-06T07:16:07.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
# 29  2023-04-06T07:16:07.000Z  ELIGIBLE        ELIGIBLE   {}  {'qiGrade': 4}
#
# [2679 rows x 16 columns]

# %%
stat = []
chunk_size = 200

for i in range(0, len(keyword_id), chunk_size):

    uri = '/stats'
    method = 'GET'
    r = requests.get(BASE_URL + uri, params={'ids': keyword_id[i:i+chunk_size], 'fields': '["clkCnt","impCnt","salesAmt", "ctr", "cpc", "avgRnk", "ccnt"]', 'timeRange': '{"since":"2023-04-01","until":"2023-04-01"}'}, headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))
    stat.append(r.json())

# %%
df4 = pd.DataFrame()
for i in stat:
    df = pd.DataFrame(i['data'])
    df4 = pd.concat([df4, df])

# %%
df4
# Out:
#       ctr  clkCnt  cpc  ccnt  avgRnk                           id  impCnt  \
# 0    0.00       0    0     0     1.0  nkw-a001-01-000004406454600       1
# 1    0.00       0    0     0     1.0  nkw-a001-01-000004406454606       3
# 2    0.00       0    0     0     2.0  nkw-a001-01-000004406429072       4
# 3    0.00       0    0     0     2.0  nkw-a001-01-000004410468510       1
# 4    0.00       0    0     0     1.6  nkw-a001-01-000004406454602      17
# ..    ...     ...  ...   ...     ...                          ...     ...
# 15  16.67       1    0     0     1.0  nkw-a001-04-000004630960779       6
# 16   0.00       0    0     0     1.0  nkw-a001-04-000004753478570       4
# 17   0.00       0    0     0     1.0  nkw-a001-04-000005088558467       2
# 18   0.00       0    0     0     1.0  nkw-a001-04-000004738329492       1
# 19   6.67       1    0     0     1.0  nkw-a001-04-000004753478584      15
#
#     salesAmt
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 15         0
# 16         0
# 17         0
# 18         0
# 19         0
#
# [216 rows x 8 columns]

# %%
df5 = pd.merge(df4, df3, how='left', left_on='id', right_on='nccKeywordId')
df6 = pd.merge(df5, df2, how='left', left_on='nccAdgroupId', right_on='nccAdgroupId')
df7 = pd.merge(df6, df1, how='left', left_on='nccCampaignId_x', right_on='nccCampaignId')

# %%
df7.columns
# Out:
# Index(['ctr', 'clkCnt', 'cpc', 'ccnt', 'avgRnk', 'id', 'impCnt', 'salesAmt',
#        'nccKeywordId', 'keyword', 'customerId_x', 'nccAdgroupId',
#        'nccCampaignId_x', 'userLock_x', 'inspectStatus', 'bidAmt_x',
#        'useGroupBidAmt', 'delFlag_x', 'regTm_x', 'editTm_x', 'status_x',
#        'statusReason_x', 'attr', 'nccQi', 'customerId_y', 'nccCampaignId_y',
#        'mobileChannelId', 'pcChannelId', 'bidAmt_y', 'name_x', 'userLock_y',
#        'useDailyBudget_x', 'useKeywordPlus', 'keywordPlusWeight',
#        'contentsNetworkBidAmt', 'useCntsNetworkBidAmt',
#        'mobileNetworkBidWeight', 'pcNetworkBidWeight', 'dailyBudget_x',
#        'budgetLock', 'delFlag_y', 'regTm_y', 'editTm_y', 'targetSummary',
#        'pcChannelKey', 'mobileChannelKey', 'status_y', 'statusReason_y',
#        'expectCost_x', 'migType_x', 'adgroupAttrJson', 'adRollingType',
#        'adgroupType', 'systemBiddingType', 'useCntsNetworkBidWeight',
#        'contentsNetworkBidWeight', 'sharedBudgetLock', 'productGroup',
#        'nccCampaignId', 'customerId', 'name_y', 'userLock', 'campaignTp',
#        'deliveryMethod', 'trackingUrl', 'trackingMode', 'usePeriod',
#        'dailyBudget_y', 'useDailyBudget_y', 'totalChargeCost', 'status',
#        'statusReason', 'expectCost_y', 'migType_y', 'delFlag', 'regTm',
#        'editTm'],
#       dtype='object')

# %%
df7[['nccCampaignId', 'name_y', 'nccAdgroupId', 'name_x', 'nccKeywordId', 'keyword', 'ctr', 'clkCnt', 'cpc', 'ccnt', 'avgRnk', 'id', 'impCnt', 'salesAmt']].to_clipboard()
